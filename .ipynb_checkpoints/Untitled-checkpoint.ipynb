# %%
# %matplotlib inline
import pandas as pd

import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
bikes = pd.read_csv("/Users/isabellaleao/Desktop/22-2c-cd-p2-grupo_isa-mari_p2-1/bike.csv",encoding= 'unicode_escape')
bikes
# Out:
#             Date  Rented Bike Count  Hour  Temperature(°C)  Humidity(%)  \
# 0     01/12/2017                254     0             -5.2           37
# 1     01/12/2017                204     1             -5.5           38
# 2     01/12/2017                173     2             -6.0           39
# 3     01/12/2017                107     3             -6.2           40
# 4     01/12/2017                 78     4             -6.0           36
# ...          ...                ...   ...              ...          ...
# 8755  30/11/2018               1003    19              4.2           34
# 8756  30/11/2018                764    20              3.4           37
# 8757  30/11/2018                694    21              2.6           39
# 8758  30/11/2018                712    22              2.1           41
# 8759  30/11/2018                584    23              1.9           43
#
#       Wind speed (m/s)  Visibility (10m)  Dew point temperature(°C)  \
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(bikes["Rented Bike Count"])
# Out:
# (array([3648., 1619., 1310.,  910.,  514.,  406.,  250.,   61.,   26.,
#           16.]),
#  array([   0. ,  355.6,  711.2, 1066.8, 1422.4, 1778. , 2133.6, 2489.2,
#         2844.8, 3200.4, 3556. ]),
#  <BarContainer object of 10 artists>)

# %%
bikes.corr()["Rented Bike Count"].sort_values()
# Out:
# Humidity(%)                 -0.199780
# Snowfall (cm)               -0.141804
# Rainfall(mm)                -0.123074
# Wind speed (m/s)             0.121108
# Visibility (10m)             0.199280
# Solar Radiation (MJ/m2)      0.261837
# Dew point temperature(°C)    0.379788
# Hour                         0.410257
# Temperature(°C)              0.538558
# Rented Bike Count            1.000000
# Name: Rented Bike Count, dtype: float64

# %% [markdown]
# As variáveis que mais influenciam a quantidade de bicicletas alugadas por hora são:
#
# Temperature(°C)
# Hour
# Dew point temperature(°C)
# Solar Radiation (MJ/m2)
# Visibility (10m)
# Wind speed (m/s)
